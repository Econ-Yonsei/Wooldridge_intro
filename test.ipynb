# %% [markdown]
# <a href="https://colab.research.google.com/github/Econ-Yonsei/Wooldridge_intro/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Welcome to colab')
# Out:
# Welcome to colab
